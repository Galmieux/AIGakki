# %% [markdown]
# <a href="https://colab.research.google.com/github/Galmieux/AIGakki/blob/main/KnowLedgeGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neo4j

# %%
from neo4j import GraphDatabase

# Neo4jの接続情報を設定
uri = "neo4j+s://78f54f8e.databases.neo4j.io"
user = "<neo4j>"
password = "<WWDmg5s6TYphbID5JL7q5Gcb9QW0QkoHTtBH3ZUQNfQ>"
NEO4J_DATABASE = "neo4j"

driver = GraphDatabase.driver(uri, auth=(user, password))

def close_driver():
    driver.close()

# %%
def create_knowledge_graph(tx):
    # ノードの作成
    tx.run("CREATE (a:Person {name: 'Alice'})")
    tx.run("CREATE (b:Person {name: 'Bob'})")
    tx.run("CREATE (c:Person {name: 'Carol'})")

    # リレーションシップの作成
    tx.run("MATCH (a:Person {name: 'Alice'}), (b:Person {name: 'Bob'}) "
           "CREATE (a)-[:KNOWS]->(b)")
    tx.run("MATCH (b:Person {name: 'Bob'}), (c:Person {name: 'Carol'}) "
           "CREATE (b)-[:KNOWS]->(c)")

# %%
with driver.session() as session:
    session.execute_write(create_knowledge_graph)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 with driver.session() as session:
# ----> 2     session.execute_write(create_knowledge_graph)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/neo4j/_sync/work/session.py:759, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     708 @NonConcurrentMethodChecker.non_concurrent_method
#     709 def execute_write(
#     710     self,
#    (...)
#     714     *args: _P.args,  **kwargs: _P.kwargs
#     715 ) -> _R:
#     716     """Execute a unit of work in a managed write transaction.
#     717
#     718     .. note::
#    (...)
#     757     .. versionadded:: 5.0
#     758     """
# --> 759     return self._run_transaction(
#     760         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     761         transaction_function, args, kwargs
#     762     )
#
# ...
